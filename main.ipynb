# %%
import sqlite3
conn = sqlite3.connect("backend\data.db")
conn.row_factory = sqlite3.Row
rows = conn.execute("SELECT * FROM Shop_Total WHERE date = '05/03/2026'").fetchall()
for row in rows:
    print(dict(row))
# Out:
# {'Id': 538, 'Service': 1851.0, 'Tip': 183.61000061035156, 'GiftSold': 85.0, 'GiftRedeem': 0.0, 'Card': 1857.6099853515625, 'Cash': 252.0, 'Other': 0.0, 'Discount': 10.0, 'Withdraw': 0.0, 'Credit': 0.0, 'Totall': 2.2737367544323206e-13, 'Date': '05/03/2026', 'Supply': 29.0, 'surcharge': 0.0, 'refund': 0.0, 'option': '{"cash_expect":252.0,"staff_discount":0.0,"other":{},"product":0.0,"card_expect":1857.61,"ext_terminal_count":true,"shop_income":747.8,"staff_cash_hold":0.0,"tax":0.0,"staff_settle":"OWNER","staff_income":1276.81}'}
