# %%
import sqlite3
conn = sqlite3.connect("backend\data.db")
conn.row_factory = sqlite3.Row
rows = conn.execute("SELECT * FROM Bill WHERE Day IS NULL").fetchall()
for row in rows:
    print(dict(row))
# Out:
# {'Id': 0, 'Service': 37.0, 'Tip': 0.0, 'Day': None, 'Hour': '10:29 AM', 'Discount': 0.0, 'Cash': 0.0, 'Card': 0.0, 'Other': 37.0, 'Gift': 0.0, 'Note': '{"gift":[],"note":"","other":[{"amount":"37.0","name":"Check"}],"gift_sale":[],"discount":{},"tax":0.0,"employee":{"PHI":28748},"card":{},"promotion":[]}', 'realday': '05/04/2026', 'surcharge': 0.0, 'table_id': 20674}
# {'Id': 3, 'Service': 100.0, 'Tip': 25.0, 'Day': None, 'Hour': '11:03 AM', 'Discount': 0.0, 'Cash': 0.0, 'Card': 125.0, 'Other': 0.0, 'Gift': 0.0, 'Note': '{"gift":[],"note":"","other":[],"gift_sale":[],"discount":{},"tax":0.0,"employee":{"DALI":28751,"LEE":28752},"card":{"1":"125.00"},"promotion":[]}', 'realday': '05/04/2026', 'surcharge': 0.0, 'table_id': 20675}
# ...
