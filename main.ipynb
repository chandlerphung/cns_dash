# %%
import sqlite3
conn = sqlite3.connect("backend\data.db")
conn.row_factory = sqlite3.Row
rows = conn.execute("SELECT * FROM Request_Service WHERE ddate = '05/05/2026'").fetchall()
for row in rows:
    print(dict(row))
# Out:
# {'id': 17403, 'timeend': None, 'timestart': None, 'customer': 'Kai', 'service': '[{"init":"Open","customer_num":"1","turn":0.0,"supply":0.0,"phone":"3132091024","price":0.0,"background":"#1a1a1a","name":"Open","andup":false,"forthground":"#cccccc","time":0.0,"customer_name":"Kai","option":{}}]', 'ddate': '05/05/2026', 'appointment': None, 'num': 1, 'hour': '09:22', 'request': None, 'phone': '3132091024', 'option': '{"birthday":false,"new_customer":false,"member":false,"warning":false,"vip":false}'}
